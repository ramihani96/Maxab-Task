# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'iframe_connected'
# %matplotlib inline

# %% [markdown]
# # Task 7 - Calculate Days On Hand for all SKUs

# %%
# Reading Data
stock_data = pd.read_excel("dataset2.xlsx", sheet_name='Stocks')
sales_data = pd.read_excel("dataset2.xlsx", sheet_name='Sales')

# %% [markdown]
# ## 1. Getting the Total Number of Sales of each SKU During The 10 Days Period

# %%
total_sales_per_sku = pd.pivot_table(sales_data, 
                                     index='sku', 
                                     values='Sales_Count', 
                                     aggfunc='sum')
total_sales_per_sku
# Out:
#                                                    Sales_Count
# sku
# AA سوني زنك (شرنك) - 4 حجر                                   8
# AA فيليبس (شرنك) - 4 حجر                                    20
# AAAفيليبس الكالين كارت - 2 حجر                               1
# D فيليبس (شرنك) - 2 حجر                                      9
# أرز  الضحى مصرى - 5 كيلو                                    46
# ...                                                        ...
# ويفر فانيليا بسكو مصر - 2 جنية                             186
# ويفر كتاكيتو مغطي بالشوكولاته - 5 جنية                     221
# ويفر كتاكيتو ميني - 3 جنية                                 207
# ويفر كوماندا بيور محشو بكريمه الشوكولاته - 2 جنية            1
# ويفرالشمعدان اخضر فاخر - 2 جنية                             91
#
# [897 rows x 1 columns]

# %% [markdown]
# ## 2. Merging Stock and Sales data

# %%
# Set 'sku' as index & Adding Total Sold Items Per SKU
stock_data.set_index('sku', inplace=True)
stock_sales_data = total_sales_per_sku.merge(stock_data, how='left', left_index=True, right_index=True).reset_index()
stock_sales_data.drop_duplicates('sku', inplace=True)
stock_sales_data.rename(columns={'Sales_Count': 'total_sold_items'}, inplace=True)
stock_sales_data.reset_index(inplace=True, drop=True)
stock_sales_data
# Out:
#                                                    sku  total_sold_items  \
# 0                           AA سوني زنك (شرنك) - 4 حجر                 8
# 1                             AA فيليبس (شرنك) - 4 حجر                20
# 2                       AAAفيليبس الكالين كارت - 2 حجر                 1
# 3                              D فيليبس (شرنك) - 2 حجر                 9
# 4                             أرز  الضحى مصرى - 5 كيلو                46
# ..                                                 ...               ...
# 892                     ويفر فانيليا بسكو مصر - 2 جنية               186
# 893             ويفر كتاكيتو مغطي بالشوكولاته - 5 جنية               221
# 894                         ويفر كتاكيتو ميني - 3 جنية               207
# 895  ويفر كوماندا بيور محشو بكريمه الشوكولاته - 2 جنية                 1
# 896                    ويفرالشمعدان اخضر فاخر - 2 جنية                91
#
#      Stock
# 0       78
# 1       50
# 2       15
# 3       87
# 4      114
# ..     ...
# 892    253
# 893    536
# 894    632
# 895     26
# 896    221
#
# [897 rows x 3 columns]

# %% [markdown]
# ## 3. Calculating Days On Hand For each SKU

# %%
# Calculate Days On Hand for each SKU
# Period = 10 Days
stock_sales_data['days_on_hand'] = np.floor(stock_sales_data['Stock'] / (stock_sales_data['total_sold_items'] / 10))
stock_sales_data
# Out:
#                                                    sku  total_sold_items  \
# 0                           AA سوني زنك (شرنك) - 4 حجر                 8
# 1                             AA فيليبس (شرنك) - 4 حجر                20
# 2                       AAAفيليبس الكالين كارت - 2 حجر                 1
# 3                              D فيليبس (شرنك) - 2 حجر                 9
# 4                             أرز  الضحى مصرى - 5 كيلو                46
# ..                                                 ...               ...
# 892                     ويفر فانيليا بسكو مصر - 2 جنية               186
# 893             ويفر كتاكيتو مغطي بالشوكولاته - 5 جنية               221
# 894                         ويفر كتاكيتو ميني - 3 جنية               207
# 895  ويفر كوماندا بيور محشو بكريمه الشوكولاته - 2 جنية                 1
# 896                    ويفرالشمعدان اخضر فاخر - 2 جنية                91
#
#      Stock  days_on_hand
# 0       78          97.0
# 1       50          25.0
# 2       15         150.0
# 3       87          96.0
# 4      114          24.0
# ..     ...           ...
# 892    253          13.0
# 893    536          24.0
# 894    632          30.0
# 895     26         260.0
# 896    221          24.0
#
# [897 rows x 4 columns]

# %% [markdown]
# ## 4. Visualizing Top and Lowest SKUs in terms of Days On Hand

# %%
# Get The Highest 10 Days On Hand Items
top_10_items = stock_sales_data.sort_values(by='days_on_hand', ascending=False).head(10)

# Plot the results
fig =  px.bar(data_frame= top_10_items,
              x='sku', 
              y='days_on_hand',
              color='days_on_hand',
              text='days_on_hand',
              color_continuous_scale='deep')

fig.update_xaxes(ticklabelposition="inside top", title='SKU')
fig.update_yaxes(ticklabelposition="inside top", title='Days On Hand')
fig.update_layout(font=dict(family='Arial', size=16), 
                  width=1400, 
                  height=900)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="1420px"
#     height="920"
#     src="iframe_figures/figure_6.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### 5- Items With Zero Days On Hand (Out Of Stock in 0 Days)

# %%
# Select Items that are going to be out of stock in 0 days
zero_days_on_hand = stock_sales_data[stock_sales_data['days_on_hand'] == 0]
zero_days_on_hand
# Out:
#                                                    sku  total_sold_items  \
# 139  تاوتاو كيك  الحليب مغطي بالشوكولاتةالبيضاء - 2...                39
# 171                 جبنة دومتي بلس بالزيتون - 500 جرام                67
# 218               حلوى هولز مينتول كبير 9 قطع - 5 جنية                15
# 239                                دقيق الضحي - 1 كيلو               394
# 244                         ذرة فيشار الضحى - 500 جرام               278
# 302                    سائل اطباق بريل متكرر - 35 جرام               293
# 354         شاى ليبتون أخضر بدون مرارة (عرض) - 25 فتلة               164
# 362           شاي ليبتون اخضر بالنعناع (عرض) - 25 فتلة               279
# 394      صابون جو كريمي مع الصبار و الليمون - 125 جرام                40
# 395                 صابون جو كريمي مع اللوز - 125 جرام                47
# 407                    صابون ديتول جدد نشاطك - 60 جرام               209
# 420                          صابون لوكس عرض - 120 جرام                69
# 467                  عصير بيتي جوافة (بلاستيك) - 1 لتر               187
# 551                  فيبا ليمون +600 جرام هدية - 4 لتر               507
# 583                             كارت اتصالات - 25 جنية                14
# 593                            كارت فودافون - 100 جنية                26
# 596                           كارت فودافون - 4.25 جنية               757
# 597                             كارت فودافون - 50 جنية                63
# 614                           كلور كلوريل  - 1050 جرام                79
# 639                             كيك دروو زبده - 5 جنية              1562
# 679                  لبن بيتي كامل الدسم (عرض) - 1 لتر                25
# 680                        لبن بيتي كامل الدسم - 1 لتر               143
# 722             مرقة خضار فاين فودز 12 مكعب - 108 جرام               250
# 779                     مشروب طاقة ستينج زجاج - 275 مل               106
# 856                            مياه اكوافينا - 1.5 لتر               979
# 867               نسكافية بندق 3*1 ظرف (عرض) - 18 جرام                97
#
#      Stock  days_on_hand
# 139      3           0.0
# 171      5           0.0
# 218      1           0.0
# 239     34           0.0
# 244     10           0.0
# 302      2           0.0
# 354      3           0.0
# 362      1           0.0
# 394      1           0.0
# 395      1           0.0
# 407      3           0.0
# 420      5           0.0
# 467     18           0.0
# 551      3           0.0
# 583      1           0.0
# 593      2           0.0
# 596      2           0.0
# 597      4           0.0
# 614      2           0.0
# 639     77           0.0
# 679      2           0.0
# 680     12           0.0
# 722     22           0.0
# 779      3           0.0
# 856     26           0.0
# 867      9           0.0

# %% [markdown]
# ## Task 8 - Calculate Stocks To Be Purchased From Suppliers Per SKU to reach 7 Days On Hands

# %%
# Days on hand = Stocck / (total_sold_items / # of days)
# Stock = (total_sold_items / # of days) * 7
pd.set_option('mode.chained_assignment', None)
less_than_7_doh = stock_sales_data[stock_sales_data['days_on_hand'] < 7.0]
less_than_7_doh['demand_stock'] = np.ceil(( less_than_7_doh['total_sold_items'] / 10) * 7)
less_than_7_doh['to_purchase_items_count'] = less_than_7_doh['demand_stock'] - less_than_7_doh['Stock']
less_than_7_doh
# Out:
#                                           sku  total_sold_items  Stock  \
# 9                     أرز الضحى مصري - 1 كيلو               153     84
# 16                  أرز رفيع الأهرام - 1 كيلو                50     25
# 29                         اريال جل - 2.5 لتر                18      2
# 33                   افيريدي ازرق AA - 20 حجر                37     16
# 34                  افيريدي ازرق AAA - 40 حجر                35     16
# ..                                        ...               ...    ...
# 867      نسكافية بندق 3*1 ظرف (عرض) - 18 جرام                97      9
# 868  نسكافية شوكولاتة 3*1 ظرف (عرض) - 18 جرام                99     52
# 869           نسكافية ظرف 3*1 (عرض) - 18 جرام                90     43
# 883                    هوت صوص هاينز - 165 مل                81     39
# 884     هيد أند شولدرز اكياس 2+1 (عرض) - 5 مل                39      5
#
#      days_on_hand  demand_stock  to_purchase_items_count
# 9             5.0         108.0                     24.0
# 16            5.0          35.0                     10.0
# 29            1.0          13.0                     11.0
# 33            4.0          26.0                     10.0
# 34            4.0          25.0                      9.0
# ..            ...           ...                      ...
# 867           0.0          68.0                     59.0
# 868           5.0          70.0                     18.0
# 869           4.0          63.0                     20.0
# 883           4.0          57.0                     18.0
# 884           1.0          28.0                     23.0
#
# [173 rows x 6 columns]

# %% [markdown]
# ## 2. Visualizing The Number of SKUs needed to be purchased to achieve 7 Days On Hand

# %%
# Plot the results
fig =  px.bar(data_frame= less_than_7_doh.sort_values('to_purchase_items_count').tail(50),
              y='sku', 
              x='to_purchase_items_count',
              color='to_purchase_items_count', 
              text='to_purchase_items_count',
              color_continuous_scale='deep', 
              orientation='h')

fig.update_xaxes(title='No of Items To Purchase')
fig.update_yaxes(title='SKU')
fig.update_layout(font=dict(family='Arial', size=16), 
                  width=1400, 
                  height=1200)

fig.write_image("Items_Purchases.png")
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="1420px"
#     height="1220"
#     src="iframe_figures/figure_9.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
